# %%
import rospy
import tf

# %%
rospy.init_node('final_project_ee517', anonymous=True)

# %%
listener = tf.TransformListener()

# %%
(trans,rot) = listener.lookupTransform('/odom', '/stickbug_base/base_footprint', rospy.Time(0))

# %%
(trans,rot)
# Out:
# ([0.12695892026046238, -0.6542705111266319, 0.13089303636765376],
#  [-0.1694083344622355,
#   -0.014960542444450014,
#   0.08619977795868966,
#   0.981655029357562])
